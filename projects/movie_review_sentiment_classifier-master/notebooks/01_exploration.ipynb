# %%
import pandas as pd
import re
from ml.model import train_model
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
# loaded_data = pd.read_csv("../data/raw/IMDB%20Dataset.csv")

# %%
# loaded_data.count()

# model, embedder, X_train, y_train, X_test, y_test = train_model(raw_data_path="../data/raw/IMDB%20Dataset.csv", store_model_path="../models/sentiment_model.pkl")
#X_test_vec, _ = embed_text(X_test, embedder)
#X_train_vec, _ = embed_text(X_train, embedder)

#preds_test = model.predict(X_test_vec)
#preds_train = model.predict(X_train_vec)

# cleaner = data_processor.clean_text
# num_rows = len(loaded_data["review"])
# processed_data = pd.DataFrame({"cleaned_data": [cleaner(loaded_data["review"][i]) for i in range(num_rows)]})

# loaded_data["review"].head()
# processed_data["cleaned_data"].head()
# print(re.findall("<br />", loaded_data["review"][0]))
# print(re.findall("<br />", processed_data["cleaned_data"][0]))
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# F:\Programering Archive\MachineLearning\movie_review_sentiment_classifier\.myenv\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='1617' max='7500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1617/7500 5:35:27 < 20:22:00, 0.08 it/s, Epoch 0.65/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
# ...

# %%
report = classification_report(y_test, preds_test, output_dict=True)
cm = confusion_matrix(y_test, preds_test)
print (report)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix For Test Data")
plt.show()

#ITER 01:  {'negative': {'precision': 0.5595153243050606, 'recall': 0.7759984183471728, 'f1-score': 0.6502112151080924, 'support': 5058.0}, 'positive': {'precision': 0.6204355108877722, 'recall': 0.3747470659651963, 'f1-score': 0.467263782010849, 'support': 4942.0}, 'accuracy': 0.5777, 'macro avg': {'precision': 0.5899754175964164, 'recall': 0.5753727421561845, 'f1-score': 0.5587374985594707, 'support': 10000.0}, 'weighted avg': {'precision': 0.5896220805142367, 'recall': 0.5777, 'f1-score': 0.5597985936714347, 'support': 10000.0}}
#ITER 02: {'negative': {'precision': 0.5360723412620405, 'recall': 0.5391459074733096, 'f1-score': 0.5376047313947757, 'support': 5058.0}, 'positive': {'precision': 0.5255444738449013, 'recall': 0.5224605422905706, 'f1-score': 0.523997970573313, 'support': 4942.0}, 'accuracy': 0.5309, 'macro avg': {'precision': 0.5308084075534709, 'recall': 0.5308032248819401, 'f1-score': 0.5308013509840444, 'support': 10000.0}, 'weighted avg': {'precision': 0.5308694691844903, 'recall': 0.5309, 'f1-score': 0.5308802701968088, 'support': 10000.0}}

# %%
report = classification_report(y_train, preds_train, output_dict=True)
cm = confusion_matrix(y_train, preds_train)
print (report)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix For Train Data")
plt.show()

#ITER 01: {'negative': {'precision': 0.9190306122448979, 'recall': 0.9032694814963393, 'f1-score': 0.9110818876131708, 'support': 19942.0}, 'positive': {'precision': 0.9054411764705882, 'recall': 0.9208794495961711, 'f1-score': 0.9130950615453063, 'support': 20058.0}, 'accuracy': 0.9121, 'macro avg': {'precision': 0.9122358943577431, 'recall': 0.9120744655462552, 'f1-score': 0.9120884745792386, 'support': 40000.0}, 'weighted avg': {'precision': 0.9122161896758701, 'recall': 0.9121, 'f1-score': 0.9120913936814402, 'support': 40000.0}}
#ITER 02: {'negative': {'precision': 0.9407074217951339, 'recall': 0.922876341390031, 'f1-score': 0.931706576216271, 'support': 19942.0}, 'positive': {'precision': 0.9247406537482873, 'recall': 0.9421677136304716, 'f1-score': 0.9333728453598064, 'support': 20058.0}, 'accuracy': 0.93255, 'macro avg': {'precision': 0.9327240377717105, 'recall': 0.9325220275102513, 'f1-score': 0.9325397107880387, 'support': 40000.0}, 'weighted avg': {'precision': 0.9327008859580427, 'recall': 0.93255, 'f1-score': 0.9325421268782967, 'support': 40000.0}}
